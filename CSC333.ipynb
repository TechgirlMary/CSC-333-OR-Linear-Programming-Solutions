# %%
# importing necessary libraries for proper code execution
import numpy as np
import matplotlib.pyplot as plt
"""
MAXIMIZE PROFIT
            Z=5x+3y
SUBJECT TO

            x+2y≤8
            3x+2y≤12
            x≥0,y≥0 (non-negativity constraints)
"""
# Define the constraints for the bakery problem
def baking_time_constraint(x):
    return (8 - x) / 2  # From x + 2y = 8

def flour_constraint(x):
    return (12 - 3 * x) / 2  # From 3x + 2y = 12

# Generate x values for the plot
x = np.linspace(0, 6, 400)

# Calculate y values for each constraint
y_baking_time = baking_time_constraint(x)
y_flour = flour_constraint(x)

# Set up the plot
plt.figure(figsize=(8, 6))

# Plot the constraint lines
plt.plot(x, y_baking_time, label=r'$x + 2y \leq 8$', color='blue')
plt.plot(x, y_flour, label=r'$3x + 2y \leq 12$', color='green')

# Highlight the feasible region
y_fill = np.minimum(y_baking_time, y_flour)
plt.fill_between(x, y_fill, 0, where=(y_fill >= 0), color='gray', alpha=0.3, label='Feasible Region')

# Set axis limits
plt.xlim(0, 6)
plt.ylim(0, 6)

# Label the plot
plt.title('Graphical Solution to Maximize Bakery Profit')
plt.xlabel('Units of Chocolate Cakes (x)')
plt.ylabel('Units of Vanilla Cakes (y)')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
# importing necessary libraries for proper code execution
import numpy as np
import matplotlib.pyplot as plt
"""
MAXIMIZE
            Z=8x+7y
SUBJECT TO

            3x+4y≤12
            2x+y≤6
            x≥0,y≥0 (non-negativity constraints)
"""
# Define the constraints
def labor_constraint(x):
    return (12 - 3 * x) / 4  # From 3x + 4y = 12

def capital_constraint(x):
    return (6 - 2 * x)  # From 2x + y = 6

# Generate x values for the plot
x = np.linspace(0, 6, 400)

# Calculate y values for each constraint
y_labor = labor_constraint(x)
y_capital = capital_constraint(x)

# Set up the plot
plt.figure(figsize=(8, 6))

# Plot the constraint lines
plt.plot(x, y_labor, label=r'$3x + 4y \leq 12$', color='blue')
plt.plot(x, y_capital, label=r'$2x + y \leq 6$', color='green')

# Highlight the feasible region
y_fill = np.minimum(y_labor, y_capital)
plt.fill_between(x, y_fill, 0, where=(y_fill >= 0), color='gray', alpha=0.3, label='Feasible Region')

# Set axis limits
plt.xlim(0, 5)
plt.ylim(0, 5)

# Label the plot
plt.title('Graphical Solution to Maximize Profit')
plt.xlabel('Units of Project P1 (x)')
plt.ylabel('Units of Project P2 (y)')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
# importing necessary libraries for proper code execution
import numpy as np
import matplotlib.pyplot as plt

"""
MAXIMIZE PROFIT
            Z=500000x+400000y
SUBJECT TO

            4000x+3000y≤5000
            2000x+2500y≤4500
            1000x+1500y≤3000
            x≥0,y≥0 (non-negativity constraints)
"""
# Define the constraints for the advertising campaigns
def tv_budget_constraint(x):
    return (5000 - 4000 * x) / 3000  # From 4000x + 3000y <= 5000

def print_media_budget_constraint(x):
    return (4500 - 2000 * x) / 2500  # From 2000x + 2500y <= 4500

def social_media_budget_constraint(x):
    return (3000 - 1000 * x) / 1500  # From 1000x + 1500y <= 3000

# Generate x values for the plot
x = np.linspace(0, 2, 400)

# Calculate y values for each constraint
y_tv = tv_budget_constraint(x)
y_print_media = print_media_budget_constraint(x)
y_social_media = social_media_budget_constraint(x)

# Set up the plot
plt.figure(figsize=(8, 6))

# Plot the constraint lines
plt.plot(x, y_tv, label=r'$4000x + 3000y \leq 5000$', color='blue')
plt.plot(x, y_print_media, label=r'$2000x + 2500y \leq 4500$', color='green')
plt.plot(x, y_social_media, label=r'$1000x + 1500y \leq 3000$', color='red')

# Highlight the feasible region
y_fill = np.minimum(np.minimum(y_tv, y_print_media), y_social_media)
plt.fill_between(x, y_fill, 0, where=(y_fill >= 0), color='gray', alpha=0.3, label='Feasible Region')

# Set axis limits
plt.xlim(0, 2)
plt.ylim(0, 2)

# Label the plot
plt.title('Graphical Solution to Maximize Reach of Advertising Campaigns')
plt.xlabel('Units of Campaign A (x)')
plt.ylabel('Units of Campaign B (y)')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
# importing necessary libraries for proper code execution
import numpy as np
import matplotlib.pyplot as plt

"""
MINIMIZE
            Z=2x+5y
SUBJECT TO

            x+2y≤6
            2x+y≤5
            x≥0,y≥0 (non-negativity constraints)
"""
# Define the constraint equations
def constraint1(x):
    return (6 - x) / 2  # From x + 2y = 6

def constraint2(x):
    return (5 - 2*x)  # From 2x + y = 5

# Generate x values for the plot
x = np.linspace(0, 5, 400)

# Calculate y values for each constraint
y1 = constraint1(x)
y2 = constraint2(x)

# Set up the plot
plt.figure(figsize=(8, 6))

# Plot the constraint lines
plt.plot(x, y1, label=r'$x + 2y \leq 6$', color='blue')
plt.plot(x, y2, label=r'$2x + y \leq 5$', color='green')

# Highlight the feasible region
y_fill = np.minimum(y1, y2)
plt.fill_between(x, y_fill, 0, where=(y_fill >= 0), color='gray', alpha=0.3, label='Feasible Region')

# Set axis limits
plt.xlim(0, 4)
plt.ylim(0, 3)

# Label the plot
plt.title('Graphical Solution to Minimize Production Cost')
plt.xlabel('Units of Product X (x)')
plt.ylabel('Units of Product Y (y)')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
# importing necessary libraries for proper code execution
import numpy as np
import matplotlib.pyplot as plt

"""
MAXIMIZE
            Z=4x+5y
SUBJECT TO

            x+3y≤20
            x+2y≤15
            x≥0,y≥0 (non-negativity constraints)
"""
# Define the constraints
def budget_constraint(x):
    return (20 - x) / 2  # From x + 2y = 20

def capacity_constraint(x):
    return (15 - x) / 2  # From x + 2y = 15

# Generate x values for the plot
x = np.linspace(0, 20, 400)

# Calculate y values for each constraint
y_budget = budget_constraint(x)
y_capacity = capacity_constraint(x)

# Set up the plot
plt.figure(figsize=(8, 6))

# Plot the constraints
plt.plot(x, y_budget, label=r'$x + 2y \leq 20$', color='blue')
plt.plot(x, y_capacity, label=r'$x + 2y \leq 15$', color='green')

# Highlight the feasible region
y_fill = np.minimum(y_budget, y_capacity)
plt.fill_between(x, y_fill, 0, where=(y_fill >= 0), color='gray', alpha=0.3, label='Feasible Region')

# Set axis limits
plt.xlim(0, 20)
plt.ylim(0, 10)

# Label the plot
plt.title('Graphical Solution to Maximize Revenue')
plt.xlabel('Units of Product A (x)')
plt.ylabel('Units of Product B (y)')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
# importing necessary libraries for proper code execution
import numpy as np
import matplotlib.pyplot as plt

"""
MAXIMIZE PROFIT
            Z=10x+12y
SUBJECT TO

            4x+3y≤30
            x+2y≤18
            3x+2y≤24
            x≥0,y≥0 (non-negativity constraints)
"""
# Define the constraints for the manufacturing problem
def labor_constraint(x):
    return (30 - 4 * x) / 3  # From 4x + 3y = 30

def material_constraint(x):
    return (18 - x) / 2  # From x + 2y = 18

def machine_time_constraint(x):
    return (24 - 3 * x) / 2  # From 3x + 2y = 24

# Generate x values for the plot
x = np.linspace(0, 7, 400)

# Calculate y values for each constraint
y_labor = labor_constraint(x)
y_material = material_constraint(x)
y_machine_time = machine_time_constraint(x)

# Set up the plot
plt.figure(figsize=(8, 6))

# Plot the constraint lines
plt.plot(x, y_labor, label=r'$4x + 3y \leq 30$', color='blue')
plt.plot(x, y_material, label=r'$x + 2y \leq 18$', color='green')
plt.plot(x, y_machine_time, label=r'$3x + 2y \leq 24$', color='red')

# Highlight the feasible region
y_fill = np.minimum(np.minimum(y_labor, y_material), y_machine_time)
plt.fill_between(x, y_fill, 0, where=(y_fill >= 0), color='gray', alpha=0.3, label='Feasible Region')

# Set axis limits
plt.xlim(0, 7)
plt.ylim(0, 10)

# Label the plot
plt.title('Graphical Solution to Maximize Revenue from Manufacturing Products')
plt.xlabel('Units of Product P1 (x)')
plt.ylabel('Units of Product P2 (y)')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
# importing necessary libraries for proper code execution
import numpy as np
import matplotlib.pyplot as plt
"""
MAXIMIZE PROFIT
            Z=6x+7y
SUBJECT TO

            3x+4y≤18
            2x+y≤10
            x≥0,y≥0 (non-negativity constraints)
"""
# Define the constraints for the transport company problem
def fuel_constraint(x):
    return (18 - 3 * x) / 4  # From 3x + 4y = 18

def driver_time_constraint(x):
    return (10 - 2 * x)  # From 2x + y = 10

# Generate x values for the plot
x = np.linspace(0, 6, 400)

# Calculate y values for each constraint
y_fuel = fuel_constraint(x)
y_driver_time = driver_time_constraint(x)

# Set up the plot
plt.figure(figsize=(8, 6))

# Plot the constraint lines
plt.plot(x, y_fuel, label=r'$3x + 4y \leq 18$', color='blue')
plt.plot(x, y_driver_time, label=r'$2x + y \leq 10$', color='green')

# Highlight the feasible region
y_fill = np.minimum(y_fuel, y_driver_time)
plt.fill_between(x, y_fill, 0, where=(y_fill >= 0), color='gray', alpha=0.3, label='Feasible Region')

# Set axis limits
plt.xlim(0, 6)
plt.ylim(0, 6)

# Label the plot
plt.title('Graphical Solution to Minimize Transport Cost')
plt.xlabel('Trips by Vehicle X (x)')
plt.ylabel('Trips by Vehicle Y (y)')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
# importing necessary libraries for proper code execution
import numpy as np
import matplotlib.pyplot as plt

"""
MAXIMIZE
            Z=5x+4y
SUBJECT TO

            2x+y≤20
            3x+2y≤30
            x+2y≤18
            x≥0,y≥0 (non-negativity constraints)
"""
# Define the constraint equations
def labor_constraint(x):
    return (20 - 2*x)  # From 2x + y = 20

def material_constraint(x):
    return (30 - 3*x) / 2  # From 3x + 2y = 30

def machine_time_constraint(x):
    return (18 - x) / 2  # From x + 2y = 18

# Generate x values for the plot
x = np.linspace(0, 15, 400)

# Calculate y values for each constraint
y1 = labor_constraint(x)
y2 = material_constraint(x)
y3 = machine_time_constraint(x)

# Set up the plot
plt.figure(figsize=(8, 6))

# Plot the constraint lines
plt.plot(x, y1, label=r'$2x + y \leq 20$', color='blue')
plt.plot(x, y2, label=r'$3x + 2y \leq 30$', color='green')
plt.plot(x, y3, label=r'$x + 2y \leq 18$', color='orange')

# Highlight the feasible region
y_fill = np.minimum(np.minimum(y1, y2), y3)
plt.fill_between(x, y_fill, 0, where=(y_fill >= 0), color='gray', alpha=0.3, label='Feasible Region')

# Set axis limits
plt.xlim(0, 12)
plt.ylim(0, 12)

# Label the plot
plt.title('Graphical Solution to Maximize Profit')
plt.xlabel('Units of Product A (x)')
plt.ylabel('Units of Product B (y)')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
# importing necessary libraries for proper code execution
import numpy as np
import matplotlib.pyplot as plt

"""
MAXIMIZE PROFIT
            Z=6x+5y
SUBJECT TO

            2x+4y≤30
            3x+2y≤24
            x+2y≤20
            x≥0,y≥0 (non-negativity constraints)
"""
# Define the constraints for the cafeteria meal problem
def meat_constraint(x):
    return (30 - 2 * x) / 4  # From 2x + 4y <= 30

def vegetable_constraint(x):
    return (24 - 3 * x) / 2  # From 3x + 2y <= 24

def rice_constraint(x):
    return (20 - x) / 2  # From x + 2y <= 20

# Generate x values for the plot
x = np.linspace(0, 12, 400)

# Calculate y values for each constraint
y_meat = meat_constraint(x)
y_vegetable = vegetable_constraint(x)
y_rice = rice_constraint(x)

# Set up the plot
plt.figure(figsize=(8, 6))

# Plot the constraint lines
plt.plot(x, y_meat, label=r'$2x + 4y \leq 30$', color='blue')
plt.plot(x, y_vegetable, label=r'$3x + 2y \leq 24$', color='green')
plt.plot(x, y_rice, label=r'$x + 2y \leq 20$', color='red')

# Highlight the feasible region
y_fill = np.minimum(np.minimum(y_meat, y_vegetable), y_rice)
plt.fill_between(x, y_fill, 0, where=(y_fill >= 0), color='gray', alpha=0.3, label='Feasible Region')

# Set axis limits
plt.xlim(0, 12)
plt.ylim(0, 12)

# Label the plot
plt.title('Graphical Solution to Maximize Cafeteria Meal Revenue')
plt.xlabel('Units of Meal A (x)')
plt.ylabel('Units of Meal B (y)')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
# importing necessary libraries for proper code execution
import numpy as np
import matplotlib.pyplot as plt
"""
MAXIMIZE PROFIT
            Z=5x+3y
SUBJECT TO

            x+2y≤8
            3x+2y≤12
            x≥0,y≥0 (non-negativity constraints)
"""
# Define the constraints for the bakery problem
def baking_time_constraint(x):
    return (8 - x) / 2  # From x + 2y = 8

def flour_constraint(x):
    return (12 - 3 * x) / 2  # From 3x + 2y = 12

# Generate x values for the plot
x = np.linspace(0, 6, 400)

# Calculate y values for each constraint
y_baking_time = baking_time_constraint(x)
y_flour = flour_constraint(x)

# Set up the plot
plt.figure(figsize=(8, 6))

# Plot the constraint lines
plt.plot(x, y_baking_time, label=r'$x + 2y \leq 8$', color='blue')
plt.plot(x, y_flour, label=r'$3x + 2y \leq 12$', color='green')

# Highlight the feasible region
y_fill = np.minimum(y_baking_time, y_flour)
plt.fill_between(x, y_fill, 0, where=(y_fill >= 0), color='gray', alpha=0.3, label='Feasible Region')

# Set axis limits
plt.xlim(0, 6)
plt.ylim(0, 6)

# Label the plot
plt.title('Graphical Solution to Maximize Bakery Profit')
plt.xlabel('Units of Chocolate Cakes (x)')
plt.ylabel('Units of Vanilla Cakes (y)')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True)
plt.legend()

# Show the plot
plt.show()
